# %% [markdown]
# ## Import libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import pylab
import math

from scipy import stats

import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# ## Loading Data

# %%
datasheet = pd.read_excel('kc_house_data.xlsx')
datasheet.fillna(0)

#seting colum
datasheet.index = datasheet['yr_built']
datasheet.drop('yr_built', axis = 1)

#removing the id
datasheet.drop('id', axis = 1)

#seting datatype
# Out:
#                      date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# yr_built
# 1955      20141013T000000  221900         3       1.00         1180      5650
# 1951      20141209T000000  538000         3       2.25         2570      7242
# 1933      20150225T000000  180000         2       1.00          770     10000
# 1965      20141209T000000  604000         4       3.00         1960      5000
# 1987      20150218T000000  510000         3       2.00         1680      8080
# ...                   ...     ...       ...        ...          ...       ...
# 2009      20140521T000000  360000         3       2.50         1530      1131
# 2014      20150223T000000  400000         4       2.50         2310      5813
# 2009      20140623T000000  402101         2       0.75         1020      1350
# 2004      20150116T000000  400000         3       2.50         1600      2388
# 2008      20141015T000000  325000         2       0.75         1020      1076
#
#           floors  waterfront  view  condition  grade  sqft_above  \
# yr_built
# 1955         1.0           0     0          3      7        1180
# 1951         2.0           0     0          3      7        2170
# 1933         1.0           0     0          3      6         770
# 1965         1.0           0     0          5      7        1050
# 1987         1.0           0     0          3      8        1680
# ...          ...         ...   ...        ...    ...         ...
# 2009         3.0           0     0          3      8        1530
# 2014         2.0           0     0          3      8        2310
# 2009         2.0           0     0          3      7        1020
# 2004         2.0           0     0          3      8        1600
# 2008         2.0           0     0          3      7        1020
#
#           sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# yr_built
# 1955                  0      1955             0    98178  47.5112 -122.257
# 1951                400      1951          1991    98125  47.7210 -122.319
# 1933                  0      1933             0    98028  47.7379 -122.233
# 1965                910      1965             0    98136  47.5208 -122.393
# 1987                  0      1987             0    98074  47.6168 -122.045
# ...                 ...       ...           ...      ...      ...      ...
# 2009                  0      2009             0    98103  47.6993 -122.346
# 2014                  0      2014             0    98146  47.5107 -122.362
# 2009                  0      2009             0    98144  47.5944 -122.299
# 2004                  0      2004             0    98027  47.5345 -122.069
# 2008                  0      2008             0    98144  47.5941 -122.299
#
#           sqft_living15  sqft_lot15
# yr_built
# 1955               1340        5650
# 1951               1690        7639
# 1933               2720        8062
# 1965               1360        5000
# 1987               1800        7503
# ...                 ...         ...
# 2009               1530        1509
# 2014               1830        7200
# 2009               1020        2007
# 2004               1410        1287
# 2008               1020        1357
#
# [21613 rows x 20 columns]

# %%
#chaning the date
list_date = list(datasheet.date)
year = []
day = []
month = []

contador = 0
while contador < len(list_date):
    list_date[contador] = list_date[contador].replace('T','')
    list_date[contador] = list_date[contador][0:8]
    
    year.append(list_date[contador][0:5])
    
    contador = contador + 1
    
# remover de 8 a 13
datasheet.date = list_date
datasheet['year']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-b08426e4e52d> in <module>
#      10 # remover de 8 a 13
#      11 datasheet.date = list_date
# ---> 12 datasheet['year'] = list_date[0:5]
#
# C:\Insper\Anaconda\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# C:\Insper\Anaconda\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# C:\Insper\Anaconda\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3732
#    3733             # turn me into an ndarray
# -> 3734             value = sanitize_index(value, self.index, copy=False)
#    3735             if not isinstance(value, (np.ndarray, Index)):
#    3736                 if isinstance(value, list) and len(value) > 0:
#
# C:\Insper\Anaconda\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     610
#     611     if len(data) != len(index):
# --> 612         raise ValueError("Length of values does not match length of index")
#     613
#     614     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index
